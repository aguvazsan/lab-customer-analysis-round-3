# %% [markdown]
# # Explorator Data Analysis
#
# - Que datos hay alli?
#
# - Utilizaremos Matplotlib y Seaborn (buscar info)
# - Trabajamos con Distribucion continua (buscar info)
# - Distribución Normal
# - Regresión lineal
#
# - Diferencia entre Estadistica Descriptiva vs Estadistica Diferencial
#
# Estadisticas Descriptiva es una foto
#
# - El promedio, media
# - La mediana
# - La moda, valor mas repetidos
#
# Medidas de dispercion
#
# - SD, cuanto se aleja mi muestra de mi media (mas información de mi promedio)
# - Var, forma de calcularlo (se utiliza la SD porque esta en la mismo ordende magnitud que el promedio)
# - Range, rango intercuartilico. Arboles de decisión, donde se acumulan mis datos del .25 al .50
# - Quartiles
# - Percentiles
#
# Estiacion de frecuencia, cuantos casos posibles tengo dentro de cada nota.
#
# .describe() funtion with Python
#
# Estadistica Diferencial es una prediccion de nuevos valores dato ciertas variables (Proyección)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1.05 Activity 1
#
# Refer to the file `files_for_activities/merged_clean_ver1.csv` for this exercise.
#
# 1. Import the `merged_clean_ver1.csv` file.
# 2. Check the data types of all columns in the dataframe.
# 3. Use the describe method on only the float type columns.
#
# ### Debate
#
# 4. What is the difference between population mean and sample mean.

# %%
df1= pd.read_csv('merged_clean_ver1.csv')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3993 entries, 0 to 3992
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               3993 non-null   int64
#  1   id                       3993 non-null   int64
#  2   state                    3993 non-null   object
#  3   gender                   3993 non-null   object
#  4   median_home_val          3993 non-null   float64
#  5   median_household_income  3993 non-null   int64
#  6   ic2                      3993 non-null   float64
#  7   ic3                      3993 non-null   int64
#  8   ic4                      3993 non-null   float64
#  9   ic5                      3993 non-null   float64
#  10  avggift                  3993 non-null   float64
#  11  target_d                 3993 non-null   float64
# dtypes: float64(6), int64(4), object(2)
# memory usage: 374.5+ KB

# %%
df1.describe()
# Out:
#         Unnamed: 0             id  median_home_val  median_household_income  \
# count  3993.000000    3993.000000      3993.000000              3993.000000
# mean    499.431255   98929.308039      1158.437751               351.622840
# std     288.332533   58179.839090      1033.485773               168.488445
# min       0.000000      12.000000         0.000000                 0.000000
# 25%     250.000000   46153.000000       548.000000               239.000000
# 50%     499.000000  101432.000000       803.000000               318.000000
# 75%     749.000000  151653.000000      1349.000000               425.000000
# max    1001.000000  191779.000000      5982.000000              1500.000000
#
#                ic2          ic3          ic4            ic5      avggift  \
# count  3993.000000  3993.000000  3993.000000    3993.000000  3993.000000
# mean    400.713248   399.876283   444.732031   16456.413724    11.785117
# ...

# %% [markdown]
# # 1.05 Activity 2
#
# (_Keep working on the same file._)
#
# 1. Get the numeric data.
# 2. Use the `describe()` method on the numeric data in the DataFrame.
# 3. Print the median.
# 4. Print IQR.

# %%
df1._get_numeric_data().describe()
# Out:
#         Unnamed: 0             id  median_home_val  median_household_income  \
# count  3993.000000    3993.000000      3993.000000              3993.000000
# mean    499.431255   98929.308039      1158.437751               351.622840
# std     288.332533   58179.839090      1033.485773               168.488445
# min       0.000000      12.000000         0.000000                 0.000000
# 25%     250.000000   46153.000000       548.000000               239.000000
# 50%     499.000000  101432.000000       803.000000               318.000000
# 75%     749.000000  151653.000000      1349.000000               425.000000
# max    1001.000000  191779.000000      5982.000000              1500.000000
#
#                ic2          ic3          ic4            ic5      avggift  \
# count  3993.000000  3993.000000  3993.000000    3993.000000  3993.000000
# mean    400.713248   399.876283   444.732031   16456.413724    11.785117
# ...

# %%
summary= df1._get_numeric_data().describe().T
summary
# Out:
#                           count          mean           std       min  \
# Unnamed: 0               3993.0    499.431255    288.332533   0.00000
# id                       3993.0  98929.308039  58179.839090  12.00000
# median_home_val          3993.0   1158.437751   1033.485773   0.00000
# median_household_income  3993.0    351.622840    168.488445   0.00000
# ic2                      3993.0    400.713248    180.568500   0.00000
# ic3                      3993.0    399.876283    164.822741   0.00000
# ic4                      3993.0    444.732031    175.004178   0.00000
# ic5                      3993.0  16456.413724   9455.318118   0.00000
# avggift                  3993.0     11.785117     10.172672   2.26087
# target_d                 3993.0     15.665036     12.703041   1.00000
#
#                                 25%       50%            75%       max
# Unnamed: 0                 250.0000     499.0     749.000000    1001.0
# ...

# %%
summary['50%']
# Out:
# Unnamed: 0                    499.0
# id                         101432.0
# median_home_val               803.0
# median_household_income       318.0
# ic2                           366.0
# ic3                           365.0
# ic4                           410.0
# ic5                         14356.0
# avggift                        10.0
# target_d                       14.0
# Name: 50%, dtype: float64

# %%
summary['75%']-summary['25%']
# Out:
# Unnamed: 0                    499.000000
# id                         105500.000000
# median_home_val               801.000000
# median_household_income       186.000000
# ic2                           194.000000
# ic3                           193.000000
# ic4                           203.000000
# ic5                          7644.000000
# avggift                         7.241071
# target_d                       10.000000
# dtype: float64

# %% [markdown]
# ## Activity 3

# %%
corr_data= df1.drop(['id', 'state', 'gender'], axis=1)

corr_matrix= corr_data.corr(method= 'spearman')
corr_matrix
# Out:
#                          Unnamed: 0  median_home_val  median_household_income  \
# Unnamed: 0                 1.000000        -0.012329                 0.000009
# median_home_val           -0.012329         1.000000                 0.728291
# median_household_income    0.000009         0.728291                 1.000000
# ic2                       -0.002707         0.743631                 0.943243
# ic3                       -0.001263         0.772365                 0.972989
# ic4                       -0.001742         0.771694                 0.920689
# ic5                        0.002953         0.760386                 0.810895
# avggift                    0.014665         0.162955                 0.140066
# target_d                   0.011910         0.134380                 0.136896
#
#                               ic2       ic3       ic4       ic5   avggift  \
# Unnamed: 0              -0.002707 -0.001263 -0.001742  0.002953  0.014665
# ...

# %%
sns.heatmap(corr_matrix, annot=True)
plt.show()

# %%
pip install scipy
# Out:
# ...
#      ---------------------------------------- 0.0/42.5 MB ? eta -:--:--
#      ---------------------------------------- 0.5/42.5 MB 9.4 MB/s eta 0:00:05
#      - -------------------------------------- 1.4/42.5 MB 14.7 MB/s eta 0:00:03
#      -- ------------------------------------- 2.5/42.5 MB 20.3 MB/s eta 0:00:02
#      --- ------------------------------------ 3.8/42.5 MB 20.0 MB/s eta 0:00:02
#      ---- ----------------------------------- 5.1/42.5 MB 23.3 MB/s eta 0:00:02
#      ------ --------------------------------- 6.5/42.5 MB 23.1 MB/s eta 0:00:02
#      ------- -------------------------------- 8.1/42.5 MB 24.6 MB/s eta 0:00:02
#      -------- ------------------------------- 9.4/42.5 MB 25.1 MB/s eta 0:00:02
#      --------- ----------------------------- 10.6/42.5 MB 27.3 MB/s eta 0:00:02
#      ---------- ---------------------------- 12.0/42.5 MB 28.5 MB/s eta 0:00:02
#      ------------ -------------------------- 13.6/42.5 MB 29.7 MB/s eta 0:00:01
# ...

# %%
corr_matrix2= corr_data.corr(method= 'kendall')
corr_matrix2
# Out:
#                          Unnamed: 0  median_home_val  median_household_income  \
# Unnamed: 0                 1.000000        -0.007951                 0.000078
# median_home_val           -0.007951         1.000000                 0.543534
# median_household_income    0.000078         0.543534                 1.000000
# ic2                       -0.001785         0.559531                 0.822309
# ic3                       -0.000712         0.585792                 0.867539
# ic4                       -0.001042         0.586977                 0.774022
# ic5                        0.001898         0.579845                 0.627421
# avggift                    0.009735         0.109717                 0.094183
# target_d                   0.008247         0.094093                 0.095680
#
#                               ic2       ic3       ic4       ic5   avggift  \
# Unnamed: 0              -0.001785 -0.000712 -0.001042  0.001898  0.009735
# ...
